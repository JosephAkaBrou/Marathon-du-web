# %%
import glob
import pandas as pd

# %%
liste = glob.glob('C:/Users/joaka/Documents/Master Miashs/Marathon/*.csv')
for i in range(len(liste)):
    if i == 0 :
        db = pd.read_csv(liste[i], skiprows=2, sep=';', low_memory=False)
    else:
        db_temp = pd.read_csv(liste[i], skiprows=2, sep=';', low_memory=False)
        try:
            db_temp.drop('Libellé',axis=1, inplace=True)
        except:
            pass
        db = db.merge(db_temp, left_on='Code', right_on='Code', how='inner')

# %%
export = db[["Code","Libellé","Distance au plus proche généraliste libéral 2019",
            "Temps d'accès au généraliste libéral le plus proche 2019",
             "Nbre de généralistes lib. au 31/12 2019 Total",
             "Nbre de généralistes lib. au 31/12 2019 60> ",
             "Nbre de généralistes lib. au 31/12 2019 55 - 59",
             "Nbre de généralistes lib. au 31/12 2019 40 -  49",
             "Nbre de généralistes lib. au 31/12 2019 <40",
             "Pharmacie 2018", "Nbre de bénéficiaires d'actes gén. 2018",
             "Densité de population 2016","Taux d'emploi 2016",
             "Taux d'emploi 2016.1","Revenu fiscal médian 2016",
             "Population des moins de 18 ans 2016",
             "Population des 65 ans ou plus 2016",
             "Nombre de personnes sans diplôme 2016",
             "Nombre de personnes diplômées du supérieur 2016",
             "EHPA / EHPAD : capacité d'accueil 16-05-2019",
             "Nombre de lits et places en MCO 2017",
             "Nombre de lits en hospitalisation complète en MCO 2017"]]

# export['Code'] = export['Code'].str[:2]
export["Nbr de ben/nbr de gen"] = export["Nbre de bénéficiaires d'actes gén. 2018"]/export["Nbre de généralistes lib. au 31/12 2019 Total"]

export.columns = ['Code', 
                  'Name','DG19','TG19','NG19T','NG19_60>',
                  'NG19_55_59','NG19_40_49','NG19_<40',
                  'Pharm18','NBG18','DstPop16',
                  'TxEmpF16','TxEmpH16','RFM16','Pop16_<18','Pop16_>65',
                  '<Dpl16','>Dpl16','EHPAD19_c','NlMCO19',
                  'NlHC17','RBG_18-19']
# Out:
# C:\Users\joaka\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dep = pd.read_csv("dep/communes-departement-region.csv", sep=",", encoding="utf-8")
dep = dep.groupby(['code_commune_INSEE']).count().reset_index()
dep['code_commune_INSEE'] = dep['code_commune_INSEE'].apply(lambda x: '0'+str(x) if(len(str(x)) == 4) else str(x))
dep['code_postal'] = dep['code_postal'].apply(lambda x: '0'+str(x) if(len(str(x)) == 4) else str(x))
dep['code_dep'] = dep['code_commune_INSEE'].str[:2]
dep = dep[['code_dep','code_commune_INSEE', 
     'nom_departement','nom_region','code_postal',
     'code_region','longitude','latitude']]

# %%
merged_data = pd.merge(export,dep, left_on= "Code", right_on ="code_commune_INSEE", how="inner")
# data = pd.DataFrame(merged_data['Code'].value_counts() == 1)
# liste_code_commune = data[data['Code']==True].index
# merged_data_one = merged_data[merged_data['Code'].isin(liste_code_commune)]

# %%
len(merged_data)
# Out:
# 34962

# %%
export.to_csv("export_indicateurs.csv")
dep.to_csv("export_niveaux.csv")

# %%
mauvais_db.head(50)
# Out:
#       Code                    Name  DG19  TG19  NG19T  NG19_60>  NG19_55_59  \
# 13   01015         Arboys en Bugey   5.0   9.0      0         0           0
# 14   01015         Arboys en Bugey   5.0   9.0      0         0           0
# 29   01032               Béligneux   0.0   0.0      1         1           0
# 30   01032               Béligneux   0.0   0.0      1         1           0
# 31   01032               Béligneux   0.0   0.0      1         1           0
# 32   01032               Béligneux   0.0   0.0      1         1           0
# 36   01036      Valromey-sur-Séran   4.0   5.0      0         0           0
# 37   01036      Valromey-sur-Séran   4.0   5.0      0         0           0
# 50   01050                 Boissey   8.0  11.0      0         0           0
# 51   01050                 Boissey   8.0  11.0      0         0           0
# 54   01053         Bourg-en-Bresse   0.0   0.0     57        18          11
# 55   01053         Bourg-en-Bresse   0.0   0.0     57        18          11
# 56   01054  Bourg-Saint-Christophe   4.0   6.0      0         0           0
# 57   01054  Bourg-Saint-Christophe   4.0   6.0      0         0           0
# 63   01062              Bressolles   4.0   6.0      0         0           0
# 64   01062              Bressolles   4.0   6.0      0         0           0
# 67   01065                 Buellas   0.0   0.0      1         0           1
# 68   01065                 Buellas   0.0   0.0      1         0           1
# 81   01079   Champagne-en-Valromey   0.0   0.0      1         0           0
# 82   01079   Champagne-en-Valromey   0.0   0.0      1         0           0
# 83   01079   Champagne-en-Valromey   0.0   0.0      1         0           0
# 84   01080      Champdor-Corcelles   5.0   6.0      0         0           0
# 85   01080      Champdor-Corcelles   5.0   6.0      0         0           0
# 106  01104          Chézery-Forens   6.0   9.0      0         0           0
# 107  01104          Chézery-Forens   6.0   9.0      0         0           0
# 131  01134                 Crottet   2.0   4.0      0         0           0
# 132  01134                 Crottet   2.0   4.0      0         0           0
# 158  01165            Francheleins   6.0   7.0      0         0           0
# 159  01165            Francheleins   6.0   7.0      0         0           0
# 160  01165            Francheleins   6.0   7.0      0         0           0
# 174  01184    Hautecourt-Romanèche   5.0   7.0      0         0           0
# 175  01184    Hautecourt-Romanèche   5.0   7.0      0         0           0
# 177  01187           Haut Valromey  13.0  15.0      0         0           0
# 178  01187           Haut Valromey  13.0  15.0      0         0           0
# 179  01187           Haut Valromey  13.0  15.0      0         0           0
# 180  01187           Haut Valromey  13.0  15.0      0         0           0
# 182  01189        Injoux-Génissiat   8.0  11.0      0         0           0
# 183  01189        Injoux-Génissiat   8.0  11.0      0         0           0
# 197  01204    Le Poizat-Lalleyriat  12.0  16.0      0         0           0
# 198  01204    Le Poizat-Lalleyriat  12.0  16.0      0         0           0
# 226  01240       Matafelon-Granges   7.0   8.0      0         0           0
# 227  01240       Matafelon-Granges   7.0   8.0      0         0           0
# 232  01245    Bohas-Meyriat-Rignat   6.0   8.0      0         0           0
# 233  01245    Bohas-Meyriat-Rignat   6.0   8.0      0         0           0
# 234  01245    Bohas-Meyriat-Rignat   6.0   8.0      0         0           0
# 236  01247                  Mijoux  10.0  21.0      0         0           0
# 237  01247                  Mijoux  10.0  21.0      0         0           0
# 239  01249                 Miribel   0.0   0.0      8         0           1
# 240  01249                 Miribel   0.0   0.0      8         0           1
# 241  01249                 Miribel   0.0   0.0      8         0           1
#
#      NG19_40_49  NG19_<40  Pharm18  ...  NlHC17    RBG_18-19  code_dep  \
# 13            0         0      0.0  ...     0.0          inf        01
# 14            0         0      0.0  ...     0.0          inf        01
# 29            0         0      1.0  ...     0.0  2847.000000        01
# 30            0         0      1.0  ...     0.0  2847.000000        01
# 31            0         0      1.0  ...     0.0  2847.000000        01
# 32            0         0      1.0  ...     0.0  2847.000000        01
# 36            0         0      0.0  ...     0.0          inf        01
# 37            0         0      0.0  ...     0.0          inf        01
# 50            0         0      0.0  ...     0.0          inf        01
# 51            0         0      0.0  ...     0.0          inf        01
# 54           13         7     18.0  ...   528.0   601.052632        01
# 55           13         7     18.0  ...   528.0   601.052632        01
# 56            0         0      0.0  ...     0.0          inf        01
# 57            0         0      0.0  ...     0.0          inf        01
# 63            0         0      0.0  ...     0.0          inf        01
# 64            0         0      0.0  ...     0.0          inf        01
# 67            0         0      1.0  ...     0.0  1373.000000        01
# 68            0         0      1.0  ...     0.0  1373.000000        01
# 81            1         0      1.0  ...     0.0   556.000000        01
# 82            1         0      1.0  ...     0.0   556.000000        01
# 83            1         0      1.0  ...     0.0   556.000000        01
# 84            0         0      0.0  ...     0.0          inf        01
# 85            0         0      0.0  ...     0.0          inf        01
# 106           0         0      0.0  ...     0.0          inf        01
# 107           0         0      0.0  ...     0.0          inf        01
# 131           0         0      0.0  ...     0.0          inf        01
# 132           0         0      0.0  ...     0.0          inf        01
# 158           0         0      0.0  ...     0.0          inf        01
# 159           0         0      0.0  ...     0.0          inf        01
# 160           0         0      0.0  ...     0.0          inf        01
# 174           0         0      0.0  ...     0.0          inf        01
# 175           0         0      0.0  ...     0.0          inf        01
# 177           0         0      0.0  ...     0.0          inf        01
# 178           0         0      0.0  ...     0.0          inf        01
# 179           0         0      0.0  ...     0.0          inf        01
# 180           0         0      0.0  ...     0.0          inf        01
# 182           0         0      0.0  ...     0.0          inf        01
# 183           0         0      0.0  ...     0.0          inf        01
# 197           0         0      0.0  ...     0.0          inf        01
# 198           0         0      0.0  ...     0.0          inf        01
# 226           0         0      0.0  ...     0.0          inf        01
# 227           0         0      0.0  ...     0.0          inf        01
# 232           0         0      0.0  ...     0.0          inf        01
# 233           0         0      0.0  ...     0.0          inf        01
# 234           0         0      0.0  ...     0.0          inf        01
# 236           0         0      0.0  ...     0.0          inf        01
# 237           0         0      0.0  ...     0.0          inf        01
# 239           0         4      3.0  ...     0.0  1024.375000        01
# 240           0         4      3.0  ...     0.0  1024.375000        01
# 241           0         4      3.0  ...     0.0  1024.375000        01
#
#      code_commune_INSEE  nom_departement            nom_region  code_postal  \
# 13                01015              Ain  Auvergne-Rhône-Alpes        01300
# 14                01015              Ain  Auvergne-Rhône-Alpes        01300
# 29                01032              Ain  Auvergne-Rhône-Alpes        01360
# 30                01032              Ain  Auvergne-Rhône-Alpes        01360
# 31                01032              Ain  Auvergne-Rhône-Alpes        01360
# 32                01032              Ain  Auvergne-Rhône-Alpes        01360
# 36                01036              Ain  Auvergne-Rhône-Alpes        01260
# 37                01036              Ain  Auvergne-Rhône-Alpes        01260
# 50                01050              Ain  Auvergne-Rhône-Alpes        01190
# 51                01050              Ain  Auvergne-Rhône-Alpes        01380
# 54                01053              Ain  Auvergne-Rhône-Alpes        01000
# 55                01053              Ain  Auvergne-Rhône-Alpes        01000
# 56                01054              Ain  Auvergne-Rhône-Alpes        01800
# 57                01054              Ain  Auvergne-Rhône-Alpes        01800
# 63                01062              Ain  Auvergne-Rhône-Alpes        01360
# 64                01062              Ain  Auvergne-Rhône-Alpes        01360
# 67                01065              Ain  Auvergne-Rhône-Alpes        01310
# 68                01065              Ain  Auvergne-Rhône-Alpes        01310
# 81                01079              Ain  Auvergne-Rhône-Alpes        01260
# 82                01079              Ain  Auvergne-Rhône-Alpes        01260
# 83                01079              Ain  Auvergne-Rhône-Alpes        01260
# 84                01080              Ain  Auvergne-Rhône-Alpes        01110
# 85                01080              Ain  Auvergne-Rhône-Alpes        01110
# 106               01104              Ain  Auvergne-Rhône-Alpes        01200
# 107               01104              Ain  Auvergne-Rhône-Alpes        01410
# 131               01134              Ain  Auvergne-Rhône-Alpes        01290
# 132               01134              Ain  Auvergne-Rhône-Alpes        01750
# 158               01165              Ain  Auvergne-Rhône-Alpes        01090
# 159               01165              Ain  Auvergne-Rhône-Alpes        01090
# 160               01165              Ain  Auvergne-Rhône-Alpes        01090
# 174               01184              Ain  Auvergne-Rhône-Alpes        01250
# 175               01184              Ain  Auvergne-Rhône-Alpes        01250
# 177               01187              Ain  Auvergne-Rhône-Alpes        01260
# 178               01187              Ain  Auvergne-Rhône-Alpes        01260
# 179               01187              Ain  Auvergne-Rhône-Alpes        01260
# 180               01187              Ain  Auvergne-Rhône-Alpes        01260
# 182               01189              Ain  Auvergne-Rhône-Alpes        01200
# 183               01189              Ain  Auvergne-Rhône-Alpes        01200
# 197               01204              Ain  Auvergne-Rhône-Alpes        01130
# 198               01204              Ain  Auvergne-Rhône-Alpes        01130
# 226               01240              Ain  Auvergne-Rhône-Alpes        01580
# 227               01240              Ain  Auvergne-Rhône-Alpes        01580
# 232               01245              Ain  Auvergne-Rhône-Alpes        01250
# 233               01245              Ain  Auvergne-Rhône-Alpes        01250
# 234               01245              Ain  Auvergne-Rhône-Alpes        01250
# 236               01247              Ain  Auvergne-Rhône-Alpes        01170
# 237               01247              Ain  Auvergne-Rhône-Alpes        01410
# 239               01249              Ain  Auvergne-Rhône-Alpes        01700
# 240               01249              Ain  Auvergne-Rhône-Alpes        01700
# 241               01249              Ain  Auvergne-Rhône-Alpes        01700
#
#      code_region  longitude   latitude
# 13          84.0   5.652631  45.723762
# 14          84.0   5.652631  45.723762
# 29          84.0   5.139895  45.859146
# 30          84.0   5.139895  45.859146
# 31          84.0   5.139895  45.859146
# 32          84.0   5.139895  45.859146
# 36          84.0   5.651158  45.884748
# 37          84.0   5.651158  45.884748
# 50          84.0   4.998976  46.372797
# 51          84.0   4.998976  46.372797
# 54          84.0   5.246021  46.205152
# 55          84.0   5.246021  46.205152
# 56          84.0   5.143492  45.886193
# 57          84.0   5.143492  45.886193
# 63          84.0   5.100943  45.869423
# 64          84.0   5.100943  45.869423
# 67          84.0   5.144875  46.210414
# 68          84.0   5.144875  46.210414
# 81          84.0   5.693219  45.931645
# 82          84.0   5.693219  45.931645
# 83          84.0   5.693219  45.931645
# 84          84.0   5.600088  46.019884
# 85          84.0   5.600088  46.019884
# 106         84.0   5.872481  46.222573
# 107         84.0   5.872481  46.222573
# 131         84.0   4.877480  46.283072
# 132         84.0   4.877480  46.283072
# 158         84.0   4.812936  46.073595
# 159         84.0   4.812936  46.073595
# 160         84.0   4.812936  46.073595
# 174         84.0   5.429445  46.161124
# 175         84.0   5.429445  46.161124
# 177         84.0   5.702670  46.031741
# 178         84.0   5.702670  46.031741
# 179         84.0   5.702670  46.031741
# 180         84.0   5.702670  46.031741
# 182         84.0   5.759914  46.049773
# 183         84.0   5.759914  46.049773
# 197         84.0   5.718292  46.147959
# 198         84.0   5.718292  46.147959
# 226         84.0   5.539589  46.256532
# 227         84.0   5.539589  46.256532
# 232         84.0   5.378011  46.142706
# 233         84.0   5.378011  46.142706
# 234         84.0   5.378011  46.142706
# 236         84.0   6.009026  46.362245
# 237         84.0   6.009026  46.362245
# 239         84.0   4.941067  45.844210
# 240         84.0   4.941067  45.844210
# 241         84.0   4.941067  45.844210
#
# [50 rows x 31 columns]
